# %%
! pip3 install pandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━ 8.7/10.0 MB 701.2 kB/s eta 0:00:02
# WARNING: Connection timed out while downloading.
# WARNING: Attempting to resume incomplete download (8.7 MB/10.0 MB, attempt 1)
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("HTTPSConnection(host='files.pythonhosted.org', port=443): Failed to resolve 'files.pythonhosted.org' ([Errno 8] nodename nor servname provided, or not known)")': /packages/06/ec/5189518c7a7659c4bdcc6b1eb32c46c6f3c86b0661ffd84143d1112c7732/pandas-3.0.5-cp314-cp314-macosx_11_0_arm64.whl
# Resuming download pandas-3.0.5-cp314-cp314-macosx_11_0_arm64.whl (8.7 MB/10.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 290.4 kB/s  0:00:04m0:00:010:07
# ...

# %%
import pandas as pd

# %%
rest_data = {
    'Table_No': [12, 14, 15],
    'Bill_Amount': [1250, 890, 2400],
    'Waiter_name': ['Amit', 'Sumit', 'Rahul']
}
df=pd.DataFrame(rest_data)
print(df['Bill_Amount'])
print(type(df['Bill_Amount']))
# Out:
# 0    1250
# 1     890
# 2    2400
# Name: Bill_Amount, dtype: int64
# <class 'pandas.Series'>

# %%
import pandas as pd
food_data = (('pizza 45',
              'burger 30', 
              'pasta 35', 
              'soda 15'))
food_series = pd.Series(food_data)
print(food_series)
# Out:
# 0     pizza 45
# 1    burger 30
# 2     pasta 35
# 3      soda 15
# dtype: str

# %%
import pandas as pd
df = pd.DataFrame({
    'day': ['pizza', 'burger', 'pasta', 'soda'],
    'price': [45, 30, 35, 15]
})

present= np.array([22,18,])
x = df['day']

print(x)
print(x.shape)
# Out:
# 0     pizza
# 1    burger
# 2     pasta
# 3      soda
# Name: day, dtype: str
# (4,)
